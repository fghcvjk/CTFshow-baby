# %%
import tensorflow as tf 
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
see_model = tf.keras.applications.MobileNetV2(include_top=True, weights='imagenet')
see_model.trainable = False

# ImageNet的图像分类标注
decode_predictions = tf.keras.applications.mobilenet_v2.decode_predictions

# %%
# 或许这个能帮到你
def get_imagenet_label(probs):
  return decode_predictions(probs, top=1)[0][0]

# %%
# !unzip bigox.zip
# Out:
# Archive:  bigox.zip
#   inflating: bigox/bigox_1.npy
#   inflating: bigox/bigox_10.npy
#   inflating: bigox/bigox_11.npy
#   inflating: bigox/bigox_12.npy
#   inflating: bigox/bigox_13.npy
#   inflating: bigox/bigox_14.npy
#   inflating: bigox/bigox_15.npy
#   inflating: bigox/bigox_16.npy
#   inflating: bigox/bigox_17.npy
#   inflating: bigox/bigox_18.npy
#   inflating: bigox/bigox_19.npy
#   inflating: bigox/bigox_2.npy
#   inflating: bigox/bigox_20.npy
#   inflating: bigox/bigox_21.npy
#   inflating: bigox/bigox_22.npy
#   inflating: bigox/bigox_23.npy
#   inflating: bigox/bigox_24.npy
#   inflating: bigox/bigox_25.npy
#   inflating: bigox/bigox_26.npy
#   inflating: bigox/bigox_27.npy
#   inflating: bigox/bigox_28.npy
#   inflating: bigox/bigox_29.npy
#   inflating: bigox/bigox_3.npy
#   inflating: bigox/bigox_30.npy
#   inflating: bigox/bigox_31.npy
#   inflating: bigox/bigox_32.npy
#   inflating: bigox/bigox_4.npy
#   inflating: bigox/bigox_5.npy
#   inflating: bigox/bigox_6.npy
#   inflating: bigox/bigox_7.npy
#   inflating: bigox/bigox_8.npy
#   inflating: bigox/bigox_9.npy

# %%
img = np.load('bigox/bigox_1.npy')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %% [markdown]
# 这个see_model会看到什么样的东西呢？
#
# 轮到你了！
#
# 看看它会看到什么吧！

# %% [markdown]
# # 轮到你了！

# %%
# 怀挺！
